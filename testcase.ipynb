# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('dataset.csv')

# %%
df.dtypes
# Out:
# userid                object
# user_state            object
# event_name            object
# event_attributes      object
# event_created_date    object
# event_platform        object
# device_manufacture    object
# device_model          object
# dtype: object

# %%
df.describe()
# Out:
#                                   userid user_state event_name  \
# count                              23357      23286      23357
# unique                              3540         49         23
# top     627f50253b42607513a1c93bb68201ad         CA      Order
# freq                                 498       8627       6116
#
#                      event_attributes   event_created_date event_platform  \
# count                           23357                23357          23357
# unique                           2309                20452              3
# top     {"Premium Membership":"True"}  2022-03-16 08:20:51            ios
# freq                             5451                   17           9586
#
#        device_manufacture device_model
# count               15847        15847
# unique                 22          290
# top                 Apple   iPhone12,1
# freq                 9586         1489

# %%
df.head()
# Out:
#                              userid user_state                  event_name  \
# 0  c95c777785faec8dd910d019d7278ebe         CA         Add Vehicle Success
# 1  c95c777785faec8dd910d019d7278ebe         CA           Add Vehicle Break
# 2  f344be2d9a042b7444f3cc5279e38ef1         FL             Calculator View
# 3  c95c777785faec8dd910d019d7278ebe         CA  Add Payment Method Success
# 4  e331ed81422d8fba55520a43a872e701         IL             Sign Up Success
#
#                                     event_attributes   event_created_date  \
# 0  {"Make":"Dodge","Model":"Caravan","Color":"Whi...  2022-01-16 17:03:04
# 1                                                 {}  2022-01-16 17:07:47
# 2                                                 {}  2022-01-16 17:16:25
# 3     {"Payment Method":"Credit","Tokenized Pay":""}  2022-01-16 17:24:22
# 4                                 {"Method":"Apple"}  2022-01-16 17:34:51
#
#   event_platform device_manufacture device_model
# 0        android            samsung     SM-N975U
# 1        android            samsung     SM-N975U
# 2        android            samsung    SM-G973U1
# 3        android            samsung     SM-N975U
# 4            ios              Apple   iPhone12,1

# %%
df['event_created_date']= pd.to_datetime(df['event_created_date'])

# %%
df_index = df.set_index([df['userid'], df['event_created_date']])
unique_userids = df_index.index.get_level_values(0).unique()

filtered_df = []
for index in unique_userids:
    sliced_df = df_index.loc[index]
    subscription = sliced_df[sliced_df['event_name'] == 'Subscription Premium']
    cancelation = sliced_df[sliced_df['event_name'] == 'Subscription Premium Cancel']
    if subscription.empty or cancelation.empty:
        df_index = df_index.drop([index])
        continue
    filtered_df.append(sliced_df[(sliced_df['event_created_date'] > subscription.iloc[0]['event_created_date']) & (sliced_df['event_created_date'] < cancelation.iloc[0]['event_created_date'])])
    
filtered_df = pd.concat(filtered_df)
filtered_df = filtered_df.set_index([filtered_df['userid'], filtered_df['event_created_date']])
filtered_df = filtered_df.drop(columns=['userid', 'event_created_date'])

# %%
filtered_df
# Out:
#                                                      user_state  \
# userid                           event_created_date
# a22abda7a39d747ab674cd13224b375a 2022-01-15 23:28:37         FL
#                                  2022-01-16 02:39:15         FL
#                                  2022-01-16 02:39:28         FL
#                                  2022-01-16 02:39:48         FL
#                                  2022-01-16 02:40:39         FL
# ...                                                         ...
# 6cd4b3af304d32aefeb446632209c00d 2022-04-15 18:01:33         DC
#                                  2022-04-15 18:02:36         DC
#                                  2022-04-15 19:29:11         DC
# 387c88f25e204376acf003420663fef5 2022-04-16 18:53:16         AR
#                                  2022-04-16 18:56:00         AR
#
#                                                                                event_name  \
# userid                           event_created_date
# a22abda7a39d747ab674cd13224b375a 2022-01-15 23:28:37  Account History Transaction Details
#                                  2022-01-16 02:39:15  Account History Transaction Details
].value_counts().plot(kind='barh')
# Out:
# <AxesSubplot: >

# %%
filtered_df.loc['387c88f25e204376acf003420663fef5']
# Out:
#                     user_state                           event_name  \
# event_created_date
# 2022-04-16 18:53:16         AR  Account History Transaction Details
# 2022-04-16 18:56:00         AR                        Wallet Opened
#
#                                                       event_attributes  \
# event_created_date
# 2022-04-16 18:53:16  {"Navigated From":"Account History","Status":"...
# 2022-04-16 18:56:00                                                 {}
#
#                     event_platform device_manufacture device_model
# event_created_date
# 2022-04-16 18:53:16        android            samsung     SM-G970U
# 2022-04-16 18:56:00        android            samsung     SM-G970U

# %%
filtered_df.loc['a22abda7a39d747ab674cd13224b375a']
# Out:
#                     user_state                           event_name  \
# event_created_date
# 2022-01-15 23:28:37         FL  Account History Transaction Details
# 2022-01-16 02:39:15         FL  Account History Transaction Details
# 2022-01-16 02:39:28         FL  Account History Transaction Details
# 2022-01-16 02:39:48         FL  Account History Transaction Details
# 2022-01-16 02:40:39         FL                        Wallet Opened
# 2022-01-22 21:14:00         FL  Account History Transaction Details
# 2022-01-22 21:14:25         FL  Account History Transaction Details
# 2022-01-22 21:14:36         FL  Account History Transaction Details
# 2022-01-22 21:15:56         FL                        Wallet Opened
# 2022-01-25 16:58:58         FL  Account History Transaction Details
# 2022-01-25 16:59:12         FL  Account History Transaction Details
# 2022-01-25 16:59:33         FL                        Wallet Opened
#
#                                                       event_attributes  \
# event_created_date
# 2022-01-15 23:28:37  {"Navigated From":"Account History","Status":"...
# 2022-01-16 02:39:15  {"Navigated From":"Account History","Status":"...
# 2022-01-16 02:39:28  {"Navigated From":"Account History","Status":"...
# 2022-01-16 02:39:48  {"Navigated From":"Account History","Status":"...
# 2022-01-16 02:40:39                                                 {}
# 2022-01-22 21:14:00  {"Navigated From":"Account History","Status":"...
# 2022-01-22 21:14:25  {"Navigated From":"Account History","Status":"...
# 2022-01-22 21:14:36  {"Navigated From":"Account History","Status":"...
# 2022-01-22 21:15:56                                                 {}
# 2022-01-25 16:58:58  {"Navigated From":"Account History","Status":"...
# 2022-01-25 16:59:12  {"Navigated From":"Account History","Status":"...
# 2022-01-25 16:59:33                                                 {}
#
#                     event_platform device_manufacture device_model
# event_created_date
# 2022-01-15 23:28:37        android                LGE      LM-V350
# 2022-01-16 02:39:15        android                LGE      LM-V350
# 2022-01-16 02:39:28        android                LGE      LM-V350
# 2022-01-16 02:39:48        android                LGE      LM-V350
# 2022-01-16 02:40:39        android                LGE      LM-V350
# 2022-01-22 21:14:00        android                LGE      LM-V350
# 2022-01-22 21:14:25        android                LGE      LM-V350
# 2022-01-22 21:14:36        android                LGE      LM-V350
# 2022-01-22 21:15:56        android                LGE      LM-V350
# 2022-01-25 16:58:58        android                LGE      LM-V350
# 2022-01-25 16:59:12        android                LGE      LM-V350
# 2022-01-25 16:59:33        android                LGE      LM-V350

# %%
filtered_df.loc['387c88f25e204376acf003420663fef5']
# Out:
#                     user_state                           event_name  \
# event_created_date
# 2022-04-16 18:53:16         AR  Account History Transaction Details
# 2022-04-16 18:56:00         AR                        Wallet Opened
#
#                                                       event_attributes  \
# event_created_date
# 2022-04-16 18:53:16  {"Navigated From":"Account History","Status":"...
# 2022-04-16 18:56:00                                                 {}
#
#                     event_platform device_manufacture device_model
# event_created_date
# 2022-04-16 18:53:16        android            samsung     SM-G970U
# 2022-04-16 18:56:00        android            samsung     SM-G970U
